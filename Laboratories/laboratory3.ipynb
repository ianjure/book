# %% [markdown]
# # **Laboratory Task 3**
#
# ---
#
# <br>
#
# **Instruction**: Perform a forward and backward propagation in python using the inputs from _Laboratory Task 2_.

# %%
import numpy as np

# %%
x = np.array([1, 0, 1])
y = np.array([1])

# use relu as the activation function.

# learning rate
lr = 0.001
